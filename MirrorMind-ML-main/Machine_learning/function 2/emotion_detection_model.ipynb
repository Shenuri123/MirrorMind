# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential,load_model,Model
from keras.layers import Dense,Conv2D,Input,DepthwiseConv2D,ReLU,Add,GlobalAveragePooling2D,BatchNormalization
from keras.callbacks import ModelCheckpoint
import cv2
import numpy as np
import tensorflow as tf

# %%
# Define the data generator with rescaling and validation split
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.1)

# Define the directories for the training and testing data
dir_train = 'D:\\Data sets\\Natural Human Face Images for Emotion Recognition\\train'
dir_test = 'D:\\Data sets\\Natural Human Face Images for Emotion Recognition\\test'

# Define the image size for the model
img_size=[224,224]

# %%
checkpoint = ModelCheckpoint(
    filepath='mobilenetv2_trained_model.h5',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

# %%
train_data = datagen.flow_from_directory(
    dir_train,
    target_size=img_size,
    batch_size=16,
    class_mode='categorical',
    subset='training',
    color_mode='grayscale'
)
val_data = datagen.flow_from_directory(
    dir_train,
    target_size=img_size,
    batch_size=16,
    class_mode='categorical',
    subset='validation',
    color_mode='grayscale'
)
print(val_data.class_indices)
# Out:
# Found 4993 images belonging to 8 classes.
# Found 550 images belonging to 8 classes.
# {'anger': 0, 'contempt': 1, 'disgust': 2, 'fear': 3, 'happiness': 4, 'neutrality': 5, 'sadness': 6, 'surprise': 7}

# %%
def inverted_residual_block(inputs, filters, expansion_factor, strides):
    x = inputs
    # Pointwise convolution
    x = Conv2D(filters * expansion_factor, kernel_size=1, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    # Depthwise convolution
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    # Pointwise convolution
    x = Conv2D(filters, kernel_size=1, strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    if strides == 1:
        x = Add()([inputs, x])

    return x

# %%
def pointwise_con(inputX,filters):
    x = Conv2D(filters, kernel_size=1, strides=1, padding='same')(inputX)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

# %%
def MobileNetV2(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Initial convolution layer
    x = Conv2D(32, kernel_size=3, strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
      # Extra pointwise convolution layer to match the number of filters
    x = pointwise_con(x,16)

    # Inverted residual blocks
    # (inputs, filters, expansion_factor, strides)
    # (inputs, c, t, s)
    x = inverted_residual_block(x, 16, 1, 1)
    x = inverted_residual_block(x, 24, 6, 2)
    x = inverted_residual_block(x, 24, 6, 1)
    x = inverted_residual_block(x, 32, 6, 2)
    x = inverted_residual_block(x, 32, 6, 1)
    x = inverted_residual_block(x, 32, 6, 1)
    x = inverted_residual_block(x, 64, 6, 2)
    x = inverted_residual_block(x, 64, 6, 1)
    x = inverted_residual_block(x, 64, 6, 1)
    x = inverted_residual_block(x, 64, 6, 1)
    x = inverted_residual_block(x, 64, 6, 1)
    x = pointwise_con(x,96)
    x = inverted_residual_block(x, 96, 6, 1)
    x = inverted_residual_block(x, 96, 6, 1)
    x = inverted_residual_block(x, 160, 6, 2)
    x = inverted_residual_block(x, 160, 6, 1)
    x = inverted_residual_block(x, 160, 6, 1)
    x = pointwise_con(x,320)
    x = inverted_residual_block(x, 320, 6, 1)

    # Final convolution layer
    x = Conv2D(1280, kernel_size=1, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    # Global average pooling and output layer
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    return Model(inputs=inputs, outputs=outputs)

# %%
input_shape = (224, 224, 1)
num_classes = 8
model = MobileNetV2(input_shape, num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 32  320         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 16  528         ['re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 112, 112, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 16  272         ['re_lu_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  re_lu_2 (ReLU)                 (None, 112, 112, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 112, 112, 16  160        ['re_lu_2[0][0]']
#  v2D)                           )
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 16  64         ['depthwise_conv2d[0][0]']
#  rmalization)                   )
#
#  re_lu_3 (ReLU)                 (None, 112, 112, 16  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 16  272         ['re_lu_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 16  64         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 112, 112, 16  0           ['re_lu_1[0][0]',
#                                 )                                 'batch_normalization_4[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 14  2448        ['add[0][0]']
#                                 4)
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 14  576        ['conv2d_4[0][0]']
#  rmalization)                   4)
#
#  re_lu_4 (ReLU)                 (None, 112, 112, 14  0           ['batch_normalization_5[0][0]']
#                                 4)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 56, 56, 144)  1440       ['re_lu_4[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 144)  576        ['depthwise_conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 56, 56, 144)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 24)   3480        ['re_lu_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 24)  96          ['conv2d_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 144)  3600        ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 144)  576        ['conv2d_6[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 56, 56, 144)  0           ['batch_normalization_8[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 56, 56, 144)  1440       ['re_lu_6[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 144)  576        ['depthwise_conv2d_2[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 56, 56, 144)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 24)   3480        ['re_lu_7[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 24)  96          ['conv2d_7[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 56, 56, 24)   0           ['batch_normalization_7[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 192)  4800        ['add_1[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 192)  768        ['conv2d_8[0][0]']
#  ormalization)
#
#  re_lu_8 (ReLU)                 (None, 56, 56, 192)  0           ['batch_normalization_11[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 28, 28, 192)  1920       ['re_lu_8[0][0]']
#  onv2D)
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 192)  768        ['depthwise_conv2d_3[0][0]']
#  ormalization)
#
#  re_lu_9 (ReLU)                 (None, 28, 28, 192)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   6176        ['re_lu_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 32)  128         ['conv2d_9[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 192)  6336        ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 192)  768        ['conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 28, 28, 192)  0           ['batch_normalization_14[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 28, 28, 192)  1920       ['re_lu_10[0][0]']
#  onv2D)
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 192)  768        ['depthwise_conv2d_4[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 28, 28, 192)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   6176        ['re_lu_11[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 32)  128         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 28, 28, 32)   0           ['batch_normalization_13[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 192)  6336        ['add_2[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 192)  768        ['conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 28, 28, 192)  0           ['batch_normalization_17[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 28, 28, 192)  1920       ['re_lu_12[0][0]']
#  onv2D)
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 192)  768        ['depthwise_conv2d_5[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 28, 28, 192)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 32)   6176        ['re_lu_13[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 32)  128         ['conv2d_13[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 28, 28, 32)   0           ['add_2[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 384)  12672       ['add_3[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 384)  1536       ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 28, 28, 384)  0           ['batch_normalization_20[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 14, 14, 384)  3840       ['re_lu_14[0][0]']
#  onv2D)
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 384)  1536       ['depthwise_conv2d_6[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 64)   24640       ['re_lu_15[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 384)  24960       ['batch_normalization_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 384)  1536       ['conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_23[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 14, 14, 384)  3840       ['re_lu_16[0][0]']
#  onv2D)
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 384)  1536       ['depthwise_conv2d_7[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 64)   24640       ['re_lu_17[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_22[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 384)  24960       ['add_4[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 384)  1536       ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_26[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 14, 14, 384)  3840       ['re_lu_18[0][0]']
#  onv2D)
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 384)  1536       ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 64)   24640       ['re_lu_19[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 14, 14, 64)   0           ['add_4[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 384)  24960       ['add_5[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 384)  1536       ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_29[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 14, 14, 384)  3840       ['re_lu_20[0][0]']
#  onv2D)
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 384)  1536       ['depthwise_conv2d_9[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 64)   24640       ['re_lu_21[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 14, 14, 64)   0           ['add_5[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 384)  24960       ['add_6[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 384)  1536       ['conv2d_22[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_32[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (None, 14, 14, 384)  3840       ['re_lu_22[0][0]']
#  Conv2D)
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 384)  1536       ['depthwise_conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 64)   24640       ['re_lu_23[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 14, 14, 64)   0           ['add_6[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 96)   6240        ['add_7[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 96)  384         ['conv2d_24[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 14, 14, 96)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 576)  55872       ['re_lu_24[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 576)  2304       ['conv2d_25[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 14, 14, 576)  0           ['batch_normalization_36[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 14, 14, 576)  5760       ['re_lu_25[0][0]']
#  Conv2D)
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 576)  2304       ['depthwise_conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 14, 14, 576)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 96)   55392       ['re_lu_26[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 96)  384         ['conv2d_26[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 14, 14, 96)   0           ['re_lu_24[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 576)  55872       ['add_8[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 576)  2304       ['conv2d_27[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 14, 14, 576)  0           ['batch_normalization_39[0][0]']
#
#  depthwise_conv2d_12 (Depthwise  (None, 14, 14, 576)  5760       ['re_lu_27[0][0]']
#  Conv2D)
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 576)  2304       ['depthwise_conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 14, 14, 576)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 96)   55392       ['re_lu_28[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 96)  384         ['conv2d_28[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 14, 14, 96)   0           ['add_8[0][0]',
#                                                                   'batch_normalization_41[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 960)  93120       ['add_9[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 960)  3840       ['conv2d_29[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 14, 14, 960)  0           ['batch_normalization_42[0][0]']
#
#  depthwise_conv2d_13 (Depthwise  (None, 7, 7, 960)   9600        ['re_lu_29[0][0]']
#  Conv2D)
#
#  batch_normalization_43 (BatchN  (None, 7, 7, 960)   3840        ['depthwise_conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 7, 7, 960)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 160)    153760      ['re_lu_30[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 7, 7, 160)   640         ['conv2d_30[0][0]']
#  ormalization)
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 960)    154560      ['batch_normalization_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 960)   3840        ['conv2d_31[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 7, 7, 960)    0           ['batch_normalization_45[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (None, 7, 7, 960)   9600        ['re_lu_31[0][0]']
#  Conv2D)
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 960)   3840        ['depthwise_conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 7, 7, 960)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 160)    153760      ['re_lu_32[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 160)   640         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 7, 7, 160)    0           ['batch_normalization_44[0][0]',
#                                                                   'batch_normalization_47[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 960)    154560      ['add_10[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 960)   3840        ['conv2d_33[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 7, 7, 960)    0           ['batch_normalization_48[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 7, 7, 960)   9600        ['re_lu_33[0][0]']
#  Conv2D)
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 960)   3840        ['depthwise_conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 7, 7, 960)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 160)    153760      ['re_lu_34[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 160)   640         ['conv2d_34[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 7, 7, 160)    0           ['add_10[0][0]',
#                                                                   'batch_normalization_50[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 320)    51520       ['add_11[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 320)   1280        ['conv2d_35[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 7, 7, 320)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 7, 7, 1920)   616320      ['re_lu_35[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 7, 7, 1920)  7680        ['conv2d_36[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 7, 7, 1920)   0           ['batch_normalization_52[0][0]']
#
#  depthwise_conv2d_16 (Depthwise  (None, 7, 7, 1920)  19200       ['re_lu_36[0][0]']
#  Conv2D)
#
#  batch_normalization_53 (BatchN  (None, 7, 7, 1920)  7680        ['depthwise_conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 7, 7, 1920)   0           ['batch_normalization_53[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 7, 7, 320)    614720      ['re_lu_37[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 7, 7, 320)   1280        ['conv2d_37[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 7, 7, 320)    0           ['re_lu_35[0][0]',
#                                                                   'batch_normalization_54[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 7, 7, 1280)   410880      ['add_12[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 7, 7, 1280)  5120        ['conv2d_38[0][0]']
#  ormalization)
#
#  re_lu_38 (ReLU)                (None, 7, 7, 1280)   0           ['batch_normalization_55[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['re_lu_38[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 8)            10248       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 3,252,488
# Trainable params: 3,211,048
# Non-trainable params: 41,440
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_data, epochs=40, validation_data=val_data,callbacks=[checkpoint])
# Out:
# Epoch 1/40
# 313/313 [==============================] - ETA: 0s - loss: 1.9529 - accuracy: 0.2786
# Epoch 1: val_accuracy improved from -inf to 0.13455, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 68s 190ms/step - loss: 1.9529 - accuracy: 0.2786 - val_loss: 2.3739 - val_accuracy: 0.1345
# Epoch 2/40
# 313/313 [==============================] - ETA: 0s - loss: 1.7362 - accuracy: 0.3519
# Epoch 2: val_accuracy improved from 0.13455 to 0.13636, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 57s 181ms/step - loss: 1.7362 - accuracy: 0.3519 - val_loss: 2.1261 - val_accuracy: 0.1364
# Epoch 3/40
# 313/313 [==============================] - ETA: 0s - loss: 1.5812 - accuracy: 0.4178
# Epoch 3: val_accuracy improved from 0.13636 to 0.35818, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 56s 180ms/step - loss: 1.5812 - accuracy: 0.4178 - val_loss: 2.1510 - val_accuracy: 0.3582
# Epoch 4/40
# 313/313 [==============================] - ETA: 0s - loss: 1.4878 - accuracy: 0.4466
# Epoch 4: val_accuracy improved from 0.35818 to 0.36000, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 56s 180ms/step - loss: 1.4878 - accuracy: 0.4466 - val_loss: 2.2965 - val_accuracy: 0.3600
# Epoch 5/40
# 313/313 [==============================] - ETA: 0s - loss: 1.3873 - accuracy: 0.4853
# Epoch 5: val_accuracy did not improve from 0.36000
# 313/313 [==============================] - 56s 178ms/step - loss: 1.3873 - accuracy: 0.4853 - val_loss: 2.0379 - val_accuracy: 0.3509
# Epoch 6/40
# 313/313 [==============================] - ETA: 0s - loss: 1.3417 - accuracy: 0.5057
# Epoch 6: val_accuracy did not improve from 0.36000
# 313/313 [==============================] - 56s 178ms/step - loss: 1.3417 - accuracy: 0.5057 - val_loss: 2.1845 - val_accuracy: 0.3564
# Epoch 7/40
# 313/313 [==============================] - ETA: 0s - loss: 1.2927 - accuracy: 0.5201
# Epoch 7: val_accuracy improved from 0.36000 to 0.42000, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 56s 180ms/step - loss: 1.2927 - accuracy: 0.5201 - val_loss: 1.8521 - val_accuracy: 0.4200
# Epoch 8/40
# 313/313 [==============================] - ETA: 0s - loss: 1.2451 - accuracy: 0.5311
# Epoch 8: val_accuracy improved from 0.42000 to 0.47455, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 56s 180ms/step - loss: 1.2451 - accuracy: 0.5311 - val_loss: 1.6303 - val_accuracy: 0.4745
# Epoch 9/40
# 313/313 [==============================] - ETA: 0s - loss: 1.1907 - accuracy: 0.5530
# Epoch 9: val_accuracy did not improve from 0.47455
# 313/313 [==============================] - 56s 178ms/step - loss: 1.1907 - accuracy: 0.5530 - val_loss: 1.5273 - val_accuracy: 0.4727
# Epoch 10/40
# 313/313 [==============================] - ETA: 0s - loss: 1.1246 - accuracy: 0.5826
# Epoch 10: val_accuracy improved from 0.47455 to 0.47636, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 56s 180ms/step - loss: 1.1246 - accuracy: 0.5826 - val_loss: 1.4773 - val_accuracy: 0.4764
# Epoch 11/40
# 313/313 [==============================] - ETA: 0s - loss: 1.0831 - accuracy: 0.5976
# Epoch 11: val_accuracy did not improve from 0.47636
# 313/313 [==============================] - 56s 178ms/step - loss: 1.0831 - accuracy: 0.5976 - val_loss: 2.0066 - val_accuracy: 0.4327
# Epoch 12/40
# 313/313 [==============================] - ETA: 0s - loss: 1.0441 - accuracy: 0.6185
# Epoch 12: val_accuracy did not improve from 0.47636
# 313/313 [==============================] - 56s 178ms/step - loss: 1.0441 - accuracy: 0.6185 - val_loss: 1.9193 - val_accuracy: 0.4545
# Epoch 13/40
# 313/313 [==============================] - ETA: 0s - loss: 1.0036 - accuracy: 0.6309
# Epoch 13: val_accuracy did not improve from 0.47636
# 313/313 [==============================] - 56s 178ms/step - loss: 1.0036 - accuracy: 0.6309 - val_loss: 1.9459 - val_accuracy: 0.4655
# Epoch 14/40
# 313/313 [==============================] - ETA: 0s - loss: 0.9433 - accuracy: 0.6529
# Epoch 14: val_accuracy improved from 0.47636 to 0.52545, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 56s 180ms/step - loss: 0.9433 - accuracy: 0.6529 - val_loss: 1.6043 - val_accuracy: 0.5255
# Epoch 15/40
# 313/313 [==============================] - ETA: 0s - loss: 0.8859 - accuracy: 0.6697
# Epoch 15: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.8859 - accuracy: 0.6697 - val_loss: 2.1633 - val_accuracy: 0.4236
# Epoch 16/40
# 313/313 [==============================] - ETA: 0s - loss: 0.8349 - accuracy: 0.6928
# Epoch 16: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.8349 - accuracy: 0.6928 - val_loss: 1.6490 - val_accuracy: 0.4855
# Epoch 17/40
# 313/313 [==============================] - ETA: 0s - loss: 0.7785 - accuracy: 0.7170
# Epoch 17: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 179ms/step - loss: 0.7785 - accuracy: 0.7170 - val_loss: 1.8540 - val_accuracy: 0.4618
# Epoch 18/40
# 313/313 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.7505
# Epoch 18: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.6894 - accuracy: 0.7505 - val_loss: 1.9661 - val_accuracy: 0.4345
# Epoch 19/40
# 313/313 [==============================] - ETA: 0s - loss: 0.6218 - accuracy: 0.7807
# Epoch 19: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.6218 - accuracy: 0.7807 - val_loss: 1.9278 - val_accuracy: 0.4636
# Epoch 20/40
# 313/313 [==============================] - ETA: 0s - loss: 0.6198 - accuracy: 0.7753
# Epoch 20: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.6198 - accuracy: 0.7753 - val_loss: 2.1155 - val_accuracy: 0.4473
# Epoch 21/40
# 313/313 [==============================] - ETA: 0s - loss: 0.6385 - accuracy: 0.7683
# Epoch 21: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.6385 - accuracy: 0.7683 - val_loss: 1.8275 - val_accuracy: 0.4927
# Epoch 22/40
# 313/313 [==============================] - ETA: 0s - loss: 0.4941 - accuracy: 0.8252
# Epoch 22: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.4941 - accuracy: 0.8252 - val_loss: 2.0926 - val_accuracy: 0.4455
# Epoch 23/40
# 313/313 [==============================] - ETA: 0s - loss: 0.3934 - accuracy: 0.8620
# Epoch 23: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.3934 - accuracy: 0.8620 - val_loss: 2.1722 - val_accuracy: 0.5164
# Epoch 24/40
# 313/313 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.8748
# Epoch 24: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 180ms/step - loss: 0.3651 - accuracy: 0.8748 - val_loss: 2.8787 - val_accuracy: 0.4345
# Epoch 25/40
# 313/313 [==============================] - ETA: 0s - loss: 0.3509 - accuracy: 0.8758
# Epoch 25: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.3509 - accuracy: 0.8758 - val_loss: 2.5930 - val_accuracy: 0.4782
# Epoch 26/40
# 313/313 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.8896
# Epoch 26: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.3222 - accuracy: 0.8896 - val_loss: 2.5742 - val_accuracy: 0.4600
# Epoch 27/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2813 - accuracy: 0.9069
# Epoch 27: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.2813 - accuracy: 0.9069 - val_loss: 2.3345 - val_accuracy: 0.4891
# Epoch 28/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.9017
# Epoch 28: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 179ms/step - loss: 0.2882 - accuracy: 0.9017 - val_loss: 2.6217 - val_accuracy: 0.5055
# Epoch 29/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.9043
# Epoch 29: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 179ms/step - loss: 0.2854 - accuracy: 0.9043 - val_loss: 2.3779 - val_accuracy: 0.5164
# Epoch 30/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2396 - accuracy: 0.9247
# Epoch 30: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 55s 176ms/step - loss: 0.2396 - accuracy: 0.9247 - val_loss: 2.4773 - val_accuracy: 0.4727
# Epoch 31/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2341 - accuracy: 0.9255
# Epoch 31: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.2341 - accuracy: 0.9255 - val_loss: 2.8699 - val_accuracy: 0.5182
# Epoch 32/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2361 - accuracy: 0.9255
# Epoch 32: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.2361 - accuracy: 0.9255 - val_loss: 2.4863 - val_accuracy: 0.4673
# Epoch 33/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9285
# Epoch 33: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 179ms/step - loss: 0.2160 - accuracy: 0.9285 - val_loss: 2.8376 - val_accuracy: 0.4836
# Epoch 34/40
# 313/313 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9519
# Epoch 34: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.1604 - accuracy: 0.9519 - val_loss: 2.4583 - val_accuracy: 0.4945
# Epoch 35/40
# 313/313 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9481
# Epoch 35: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.1843 - accuracy: 0.9481 - val_loss: 2.9302 - val_accuracy: 0.4455
# Epoch 36/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9273
# Epoch 36: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.2208 - accuracy: 0.9273 - val_loss: 2.4991 - val_accuracy: 0.4927
# Epoch 37/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9237
# Epoch 37: val_accuracy did not improve from 0.52545
# 313/313 [==============================] - 56s 178ms/step - loss: 0.2280 - accuracy: 0.9237 - val_loss: 2.5286 - val_accuracy: 0.5182
# Epoch 38/40
# 313/313 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9427
# Epoch 38: val_accuracy improved from 0.52545 to 0.52727, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 56s 180ms/step - loss: 0.1857 - accuracy: 0.9427 - val_loss: 2.6893 - val_accuracy: 0.5273
# Epoch 39/40
# 313/313 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9425
# Epoch 39: val_accuracy improved from 0.52727 to 0.55636, saving model to mobilenetv2_trained_model.h5
# 313/313 [==============================] - 56s 180ms/step - loss: 0.1800 - accuracy: 0.9425 - val_loss: 2.5615 - val_accuracy: 0.5564
# Epoch 40/40
# 313/313 [==============================] - ETA: 0s - loss: 0.2030 - accuracy: 0.9357
# Epoch 40: val_accuracy did not improve from 0.55636
# 313/313 [==============================] - 56s 178ms/step - loss: 0.2030 - accuracy: 0.9357 - val_loss: 3.0003 - val_accuracy: 0.4382

# %%
img=cv2.imread("D:\\Data sets\\Natural Human Face Images for Emotion Recognition\\test\\images - 2020-11-06T003457.012_face.png",cv2.IMREAD_GRAYSCALE)
# cv2.imshow('image',img)
# cv2.waitKey(0)
img_resized=cv2.resize(img,img_size)
img=np.expand_dims(img,axis=0)
img=np.expand_dims(img,axis=-1)
img=img/255

# %%
class_names=['anger', 'contempt', 'disgust', 'fear', 'happiness', 'neutrality', 'sadness', 'surprise']
model = load_model('mobilenetv2_trained_model.h5')
pred=model.predict(img)
output_class = class_names[np.argmax(pred)]
print("predicted  class is : ",output_class)
# Out:
# 1/1 [==============================] - 1s 790ms/step
# predicted  class is :  disgust

# %%
def create_tflite():
    file_name= 'emotion_detection_model.tflite'
    converter= tf.lite.TFLiteConverter.from_keras_model(model)
    tflite_model = converter.convert()
    open(file_name,'wb').write(tflite_model)

# %%
create_tflite()
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 56). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\MDW\AppData\Local\Temp\tmp2cm1g_5n\assets
# INFO:tensorflow:Assets written to: C:\Users\MDW\AppData\Local\Temp\tmp2cm1g_5n\assets
